# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

NYT_API_KEY= os.getenv('NYT_API_KEY')
TMDB_API_KEY= os.getenv('TMDB_API_KEY')

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "(headline,web_url,snippet,source,keywords,pub_date,byline,word_count)"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
# Build parameters dictionary
params = {
    'fq': filter_query,
    'sort': sort,
    'field-name': field_list,
    'begin_date': begin_date,
    'end_date': end_date,
    'api-key': NYT_API_KEY  
}

# Make the request
response = requests.get(url, params=params)
print(response.json())
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.', 'web_url': 'https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html', 'snippet': 'A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.', 'lead_paragraph': 'A trashy treat coated in a high-art gloss, “The Attachment Diaries” gleefully kneads melodrama, noir, horror and sexual perversion into a pathological romance between two deeply damaged women.', 'print_section': 'C', 'print_page': '7', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-articleLarge.jpg', 'height': 296, 'width': 600, 'legacy': {'xlarge': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 296}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-popup.jpg', 'height': 320, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog480.jpg', 'height': 237, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog533.jpg', 'height': 263, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog427.jpg', 'height': 210, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'tmagSF', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-tmagSF.jpg', 'height': 178, 'width': 362, 'legacy': {}, 'subType': 'tmagSF', 'crop_name': 'tmagSF'}, {'rank': 0, 'subtype': 'tmagArticle', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-tmagArticle.jpg', 'height': 292, 'width': 592, 'legacy': {}, 'subType': 'tmagArticle', 'crop_name': 'tmagArticle'}, {'rank': 0, 'subtype': 'slide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-slide.jpg', 'height': 296, 'width': 600, 'legacy': {}, 'subType': 'slide', 'crop_name': 'slide'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-jumbo.jpg', 'height': 505, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-superJumbo.jpg', 'height': 780, 'width': 1583, 'legacy': {}, 'subType': 'superJumbo', 'crop_name': 'superJumbo'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog225.jpg', 'height': 111, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'master1050', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master1050.jpg', 'height': 517, 'width': 1050, 'legacy': {}, 'subType': 'master ...

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time
    params['page'] = page
    response = requests.get(url, params=params)
    
    # Make a "GET" request and retrieve the JSON
    data = response.json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    reviews_list.extend(data['response']['docs'])
        # loop through the reviews["response"]["docs"] and append each review to the list
    for review in data['response']['docs']:
        reviews_list.append(review)
        # Print the page that was just retrieved
    print(f"Page {page + 1} retrieved successfully.")

        # Print the page number that had no results then break from the loop
    if not data['response']['docs']:
        print(f"No results found on page {page + 1}. Exiting loop.")
        break
# Out:
# Page 1 retrieved successfully.
# Page 2 retrieved successfully.
# Page 3 retrieved successfully.
# Page 4 retrieved successfully.
# Page 5 retrieved successfully.
# Page 6 retrieved successfully.
# Page 7 retrieved successfully.
# Page 8 retrieved successfully.
# Page 9 retrieved successfully.
# Page 10 retrieved successfully.
# Page 11 retrieved successfully.
# Page 12 retrieved successfully.
# Page 13 retrieved successfully.
# Page 14 retrieved successfully.
# Page 15 retrieved successfully.
# Page 16 retrieved successfully.
# Page 17 retrieved successfully.
# Page 18 retrieved successfully.
# Page 19 retrieved successfully.
# Page 20 retrieved successfully.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "abstract": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "lead_paragraph": "A trashy treat coated in a high-art gloss, \u201cThe Attachment Diaries\u201d gleefully kneads melodrama, noir, horror and sexual perversion into a pathological romance between two deeply damaged women.",
#         "print_section": "C",
#         "print_page": "7",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-articleLarge.jpg",
#                 "height": 296,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 296
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-popup.jpg",
#                 "height": 320,
#                 "width": 650,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog480.jpg",
#                 "height": 237,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog533.jpg",
#                 "height": 263,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog427.jpg",
#                 "height": 210,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-tmagSF.jpg",
#                 "height": 178,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-tmagArticle.jpg",
#                 "height": 292,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-slide.jpg",
#                 "height": 296,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-jumbo.jpg",
#                 "height": 505,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-superJumbo.jpg",
#                 "height": 780,
#                 "width": 1583,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blog225.jpg",
#                 "height": 111,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master1050.jpg",
#                 "height": 517,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master675.jpg",
#                 "height": 333,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master495.jpg",
#                 "height": 244,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "master495",
#                 "crop_name": "master495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master180",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master180.jpg",
#                 "height": 89,
#                 "width": 180,
#                 "legacy": {},
#                 "subType": "master180",
#                 "crop_name": "master180"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master315",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master315.jpg",
#                 "height": 155,
#                 "width": 315,
#                 "legacy": {},
#                 "subType": "master315",
#                 "crop_name": "master315"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-master768.jpg",
#                 "height": 378,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "master768",
#                 "crop_name": "master768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-thumbStandard.jpg",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-thumbStandard.jpg",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blogSmallThumb.jpg",
#                 "height": 50,
#                 "width": 50,
#                 "legacy": {},
#                 "subType": "blogSmallThumb",
#                 "crop_name": "blogSmallThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-thumbLarge.jpg",
#                 "height": 150,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "thumbLarge",
#                 "crop_name": "thumbLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare168",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-smallSquare168.jpg",
#                 "height": 168,
#                 "width": 168,
#                 "legacy": {},
#                 "subType": "smallSquare168",
#                 "crop_name": "smallSquare168"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-smallSquare252.jpg",
#                 "height": 252,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "smallSquare252",
#                 "crop_name": "smallSquare252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square320",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-square320.jpg",
#                 "height": 320,
#                 "width": 320,
#                 "legacy": {},
#                 "subType": "square320",
#                 "crop_name": "square320"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "moth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-moth.jpg",
#                 "height": 151,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "moth",
#                 "crop_name": "moth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "filmstrip",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-filmstrip.jpg",
#                 "height": 190,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "filmstrip",
#                 "crop_name": "filmstrip"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square640",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-square640.jpg",
#                 "height": 640,
#                 "width": 640,
#                 "legacy": {},
#                 "subType": "square640",
#                 "crop_name": "square640"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquare149",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumSquare149.jpg",
#                 "height": 149,
#                 "width": 149,
#                 "legacy": {},
#                 "subType": "mediumSquare149",
#                 "crop_name": "mediumSquare149"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquareAt3X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumSquareAt3X.jpg",
#                 "height": 780,
#                 "width": 780,
#                 "legacy": {},
#                 "subType": "mediumSquareAt3X",
#                 "crop_name": "mediumSquareAt3X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "sfSpan",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-sfSpan.jpg",
#                 "height": 263,
#                 "width": 395,
#                 "legacy": {},
#                 "subType": "sfSpan",
#                 "crop_name": "sfSpan"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontal375",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-largeHorizontal375.jpg",
#                 "height": 250,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "largeHorizontal375",
#                 "crop_name": "largeHorizontal375"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontalJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-largeHorizontalJumbo.jpg",
#                 "height": 683,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "largeHorizontalJumbo",
#                 "crop_name": "largeHorizontalJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "horizontalMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-horizontalMediumAt2X.jpg",
#                 "height": 780,
#                 "width": 1170,
#                 "legacy": {},
#                 "subType": "horizontalMediumAt2X",
#                 "crop_name": "horizontalMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-hpLarge.jpg",
#                 "height": 287,
#                 "width": 511,
#                 "legacy": {},
#                 "subType": "hpLarge",
#                 "crop_name": "hpLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen573",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-largeWidescreen573.jpg",
#                 "height": 322,
#                 "width": 573,
#                 "legacy": {},
#                 "subType": "largeWidescreen573",
#                 "crop_name": "largeWidescreen573"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-largeWidescreen1050.jpg",
#                 "height": 590,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "largeWidescreen1050",
#                 "crop_name": "largeWidescreen1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "wide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-thumbWide.jpg",
#                 "height": 126,
#                 "width": 190,
#                 "legacy": {
#                     "widewidth": 190,
#                     "wideheight": 126,
#                     "wide": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-thumbWide.jpg"
#                 },
#                 "subType": "wide",
#                 "crop_name": "thumbWide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoThumb.jpg",
#                 "height": 50,
#                 "width": 75,
#                 "legacy": {},
#                 "subType": "videoThumb",
#                 "crop_name": "videoThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoLarge.jpg",
#                 "height": 507,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoLarge",
#                 "crop_name": "videoLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo210",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumThreeByTwo210.jpg",
#                 "height": 140,
#                 "width": 210,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo210",
#                 "crop_name": "mediumThreeByTwo210"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumThreeByTwo225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo225",
#                 "crop_name": "mediumThreeByTwo225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo440",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumThreeByTwo440.jpg",
#                 "height": 293,
#                 "width": 440,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo440",
#                 "crop_name": "mediumThreeByTwo440"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumThreeByTwo252.jpg",
#                 "height": 168,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo252",
#                 "crop_name": "mediumThreeByTwo252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo378",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumThreeByTwo378.jpg",
#                 "height": 252,
#                 "width": 378,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo378",
#                 "crop_name": "mediumThreeByTwo378"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoLargeAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-threeByTwoLargeAt2X.jpg",
#                 "height": 780,
#                 "width": 1170,
#                 "legacy": {},
#                 "subType": "threeByTwoLargeAt2X",
#                 "crop_name": "threeByTwoLargeAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-threeByTwoMediumAt2X.jpg",
#                 "height": 780,
#                 "width": 1170,
#                 "legacy": {},
#                 "subType": "threeByTwoMediumAt2X",
#                 "crop_name": "threeByTwoMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoSmallAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-threeByTwoSmallAt2X.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "threeByTwoSmallAt2X",
#                 "crop_name": "threeByTwoSmallAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "articleInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-articleInline.jpg",
#                 "height": 94,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "articleInline",
#                 "crop_name": "articleInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-hpSmall.jpg",
#                 "height": 80,
#                 "width": 163,
#                 "legacy": {},
#                 "subType": "hpSmall",
#                 "crop_name": "hpSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-blogSmallInline.jpg",
#                 "height": 74,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "blogSmallInline",
#                 "crop_name": "blogSmallInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumFlexible177",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mediumFlexible177.jpg",
#                 "height": 87,
#                 "width": 177,
#                 "legacy": {},
#                 "subType": "mediumFlexible177",
#                 "crop_name": "mediumFlexible177"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSmall.jpg",
#                 "height": 281,
#                 "width": 500,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoHpMedium",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoHpMedium.jpg",
#                 "height": 211,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "videoHpMedium",
#                 "crop_name": "videoHpMedium"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine600.jpg",
#                 "height": 338,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine600",
#                 "crop_name": "videoSixteenByNine600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine540",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine540.jpg",
#                 "height": 304,
#                 "width": 540,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine540",
#                 "crop_name": "videoSixteenByNine540"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine495.jpg",
#                 "height": 278,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine495",
#                 "crop_name": "videoSixteenByNine495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine390",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine390.jpg",
#                 "height": 219,
#                 "width": 390,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine390",
#                 "crop_name": "videoSixteenByNine390"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine1050",
#                 "crop_name": "videoSixteenByNine1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine480.jpg",
#                 "height": 270,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine480",
#                 "crop_name": "videoSixteenByNine480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine310",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine310.jpg",
#                 "height": 174,
#                 "width": 310,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine310",
#                 "crop_name": "videoSixteenByNine310"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine225.jpg",
#                 "height": 126,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine225",
#                 "crop_name": "videoSixteenByNine225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine96",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine96.jpg",
#                 "height": 54,
#                 "width": 96,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine96",
#                 "crop_name": "videoSixteenByNine96"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine768.jpg",
#                 "height": 432,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine768",
#                 "crop_name": "videoSixteenByNine768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine150",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNine150.jpg",
#                 "height": 84,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine150",
#                 "crop_name": "videoSixteenByNine150"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNineJumbo1600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoSixteenByNineJumbo1600.jpg",
#                 "height": 779,
#                 "width": 1387,
#                 "legacy": {},
#                 "subType": "videoSixteenByNineJumbo1600",
#                 "crop_name": "videoSixteenByNineJumbo1600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "miniMoth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-miniMoth.jpg",
#                 "height": 70,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "miniMoth",
#                 "crop_name": "miniMoth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "windowsTile336H",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-windowsTile336H.jpg",
#                 "height": 336,
#                 "width": 694,
#                 "legacy": {},
#                 "subType": "windowsTile336H",
#                 "crop_name": "windowsTile336H"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven1305",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-videoFifteenBySeven1305.jpg",
#                 "height": 609,
#                 "width": 1305,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven1305",
#                 "crop_name": "videoFifteenBySeven1305"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "facebookJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-facebookJumbo.jpg",
#                 "height": 549,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mobileMasterAt3x",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/26/multimedia/attachment1-mbcw/attachment1-mbcw-mobileMasterAt3x.jpg",
#                 "height": 780,
#                 "width": 1583,
#                 "legacy": {},
#                 "subType": "mobileMasterAt3x",
#                 "crop_name": "mobileMasterAt3x"
#             }
#         ],
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "document_type": "article",
#         "news_desk": "Weekend",
#         "section_name": "Movies",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Review",
#         "_id": "nyt://article/428e3586-a19f-5912-9f7c-6b913068e24f",
#         "word_count": 295,
#         "uri": "nyt://article/428e3586-a19f-5912-9f7c-6b913068e24f"
#     },
#     {
#         "abstract": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "lead_paragraph": "A glossy lesson in how to pour nontraditional content into a traditional rom-com mold, Shekhar Kapur\u2019s \u201cWhat\u2019s Love Got to Do With It?\u201d shapes competing notions of happily-ever-after into comfort food. And in case we\u2019re unclear about its middle-of-the-road ambitions, Kapur also gives us a film-within-the-film whose title is \u201cLove Contractually.\u201d Accordingly, anyone who takes longer than 10 minutes to forecast the ending simply doesn\u2019t get out of the house enough.",
#         "print_section": "C",
#         "print_page": "8",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-articleLarge.jpg",
#                 "height": 399,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 399
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-popup.jpg",
#                 "height": 432,
#                 "width": 650,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-blog480.jpg",
#                 "height": 319,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-blog533.jpg",
#                 "height": 354,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-blog427.jpg",
#                 "height": 284,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-tmagSF.jpg",
#                 "height": 241,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-tmagArticle.jpg",
#                 "height": 393,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-slide.jpg",
#                 "height": 399,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-jumbo.jpg",
#                 "height": 680,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-superJumbo.jpg",
#                 "height": 1361,
#                 "width": 2048,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-blog225.jpg",
#                 "height": 149,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master1050.jpg",
#                 "height": 698,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master675.jpg",
#                 "height": 448,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master495.jpg",
#                 "height": 329,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "master495",
#                 "crop_name": "master495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master180",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master180.jpg",
#                 "height": 120,
#                 "width": 180,
#                 "legacy": {},
#                 "subType": "master180",
#                 "crop_name": "master180"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master315",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master315.jpg",
#                 "height": 209,
#                 "width": 315,
#                 "legacy": {},
#                 "subType": "master315",
#                 "crop_name": "master315"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-master768.jpg",
#                 "height": 510,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "master768",
#                 "crop_name": "master768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-thumbStandard.jpg",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-thumbStandard.jpg",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/05/04/multimedia/whats-love1-fbmh/whats-love1-fbmh-blogSmallThumb.jpg",
#                 "height": 50,
#                 "width": 50,
#                 "legacy": {},
#                 "subType": "blogSmallThumb",
#                 "crop_name": "blogSmallThumb"
# ...
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-threeByTwoSmallAt2X.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "threeByTwoSmallAt2X",
#                 "crop_name": "threeByTwoSmallAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "articleInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-articleInline.jpg",
#                 "height": 107,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "articleInline",
#                 "crop_name": "articleInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-hpSmall.jpg",
#                 "height": 92,
#                 "width": 163,
#                 "legacy": {},
#                 "subType": "hpSmall",
#                 "crop_name": "hpSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-blogSmallInline.jpg",
#                 "height": 85,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "blogSmallInline",
#                 "crop_name": "blogSmallInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumFlexible177",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-mediumFlexible177.jpg",
#                 "height": 100,
#                 "width": 177,
#                 "legacy": {},
#                 "subType": "mediumFlexible177",
#                 "crop_name": "mediumFlexible177"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSmall.jpg",
#                 "height": 281,
#                 "width": 500,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoHpMedium",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoHpMedium.jpg",
#                 "height": 211,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "videoHpMedium",
#                 "crop_name": "videoHpMedium"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine600.jpg",
#                 "height": 338,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine600",
#                 "crop_name": "videoSixteenByNine600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine540",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine540.jpg",
#                 "height": 304,
#                 "width": 540,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine540",
#                 "crop_name": "videoSixteenByNine540"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine495.jpg",
#                 "height": 278,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine495",
#                 "crop_name": "videoSixteenByNine495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine390",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine390.jpg",
#                 "height": 219,
#                 "width": 390,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine390",
#                 "crop_name": "videoSixteenByNine390"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine1050",
#                 "crop_name": "videoSixteenByNine1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine480.jpg",
#                 "height": 270,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine480",
#                 "crop_name": "videoSixteenByNine480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine310",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine310.jpg",
#                 "height": 174,
#                 "width": 310,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine310",
#                 "crop_name": "videoSixteenByNine310"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine225.jpg",
#                 "height": 126,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine225",
#                 "crop_name": "videoSixteenByNine225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine96",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine96.jpg",
#                 "height": 54,
#                 "width": 96,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine96",
#                 "crop_name": "videoSixteenByNine96"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine3000",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine3000.jpg",
#                 "height": 1687,
#                 "width": 3000,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine3000",
#                 "crop_name": "videoSixteenByNine3000"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine768.jpg",
#                 "height": 432,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine768",
#                 "crop_name": "videoSixteenByNine768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine150",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNine150.jpg",
#                 "height": 84,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine150",
#                 "crop_name": "videoSixteenByNine150"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNineJumbo1600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoSixteenByNineJumbo1600.jpg",
#                 "height": 900,
#                 "width": 1600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNineJumbo1600",
#                 "crop_name": "videoSixteenByNineJumbo1600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "miniMoth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-miniMoth.jpg",
#                 "height": 70,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "miniMoth",
#                 "crop_name": "miniMoth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "windowsTile336H",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-windowsTile336H.jpg",
#                 "height": 336,
#                 "width": 694,
#                 "legacy": {},
#                 "subType": "windowsTile336H",
#                 "crop_name": "windowsTile336H"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven1305",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoFifteenBySeven1305.jpg",
#                 "height": 609,
#                 "width": 1305,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven1305",
#                 "crop_name": "videoFifteenBySeven1305"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven2610",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-videoFifteenBySeven2610.jpg",
#                 "height": 1218,
#                 "width": 2610,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven2610",
#                 "crop_name": "videoFifteenBySeven2610"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "facebookJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-facebookJumbo.jpg",
#                 "height": 550,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "verticalTwoByThree735",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-verticalTwoByThree735.jpg",
#                 "height": 1102,
#                 "width": 735,
#                 "legacy": {},
#                 "subType": "verticalTwoByThree735",
#                 "crop_name": "verticalTwoByThree735"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mobileMasterAt3x",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2023/04/20/multimedia/20other1-jfzc/20other1-jfzc-mobileMasterAt3x.jpg",
#                 "height": 1012,
#                 "width": 1800,
#                 "legacy": {},
#                 "subType": "mobileMasterAt3x",
#                 "crop_name": "mobileMasterAt3x"
#             }
#         ],
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "document_type": "article",
#         "news_desk": "Weekend",
#         "section_name": "Movies",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Review",
#         "_id": "nyt://article/ea02a29e-f843-53c0-a31d-3becb849d835",
#         "word_count": 801,
#         "uri": "nyt://article/ea02a29e-f843-53c0-a31d-3becb849d835"
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
from pandas import json_normalize

df_reviews = json_normalize(reviews_list) 
#df_reviews = pd.DataFrame(reviews_list)
df_reviews.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A glossy lesson in how to pour nontraditional ...             C          8
# 2  In “You Can Live Forever,” Jaime and Marike do...             C          9
# 3  The first thing we learn about Amanda (Rachael...             C          7
# 4  When a woman falls in love in the sensitive Fr...             C          4
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  ...  \
# 0  2023-05-25T11:00:03+0000  ...
# 1  2023-05-04T17:16:45+0000  ...
# 2  2023-05-04T11:00:08+0000  ...
# 3  2023-04-21T07:03:25+0000  ...
# 4  2023-04-20T15:35:13+0000  ...
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name  headline.seo headline.sub           byline.original  \
# 0          None          None         None    By Jeannette Catsoulis
# 1          None          None         None    By Jeannette Catsoulis
# 2          None          None         None  By Elisabeth Vincentelli
# 3          None          None         None  By Elisabeth Vincentelli
# 4          None          None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [5 rows x 27 columns]

# %%
# Extract the title from the "headline.main" column and

# save it to a new column "title"

# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

# Define a function to extract the title
def extract_title(text):
    start_index = text.find('\u2018')
    end_index = text.find('\u2019')
    if start_index != -1 and end_index != -1:
        title = text[start_index + 1:end_index]
        if not title.endswith(" Review"):
            title += " Review"
        return title

# Extract the title and save it to a new column "title" in df_reviews
df_reviews['title'] = df_reviews['headline.main'].apply(extract_title)

# Display the DataFrame to verify the changes
df_reviews.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A glossy lesson in how to pour nontraditional ...             C          8
# 2  In “You Can Live Forever,” Jaime and Marike do...             C          9
# 3  The first thing we learn about Amanda (Rachael...             C          7
# 4  When a woman falls in love in the sensitive Fr...             C          4
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  ... headline.kicker headline.content_kicker  \
# 0  2023-05-25T11:00:03+0000  ...            None                    None
# 1  2023-05-04T17:16:45+0000  ...            None                    None
# 2  2023-05-04T11:00:08+0000  ...            None                    None
# 3  2023-04-21T07:03:25+0000  ...            None                    None
# 4  2023-04-20T15:35:13+0000  ...   Critic’s pick                    None
#
#                   headline.print_headline headline.name headline.seo  \
# 0                  The Attachment Diaries          None         None
# 1          What’s Love Got to Do With It?          None         None
# 2                    You Can Live Forever          None         None
# 3              A Tourist’s  Guide to Love          None         None
# 4  Intoxicating Love With a Sobering Turn          None         None
#
#    headline.sub           byline.original  \
# 0          None    By Jeannette Catsoulis
# 1          None    By Jeannette Catsoulis
# 2          None  By Elisabeth Vincentelli
# 3          None  By Elisabeth Vincentelli
# 4          None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review
#
# [5 rows x 28 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']}; " 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords.strip()

# Fix the "keywords" column by converting cells from a list to a string
df_reviews['keywords'] = df_reviews['keywords'].apply(extract_keywords)

# Display the DataFrame to verify the changes
df_reviews.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A glossy lesson in how to pour nontraditional ...             C          8
# 2  In “You Can Live Forever,” Jaime and Marike do...             C          9
# 3  The first thing we learn about Amanda (Rachael...             C          7
# 4  When a woman falls in love in the sensitive Fr...             C          4
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  subject: Movies; creative_works: The Attachmen...
# 1  subject: Movies; persons: Kapur, Shekhar; pers...
# 2  subject: Movies; creative_works: You Can Live ...
# 3  subject: Movies; creative_works: A Tourist's G...
# 4  subject: Movies; persons: Zlotowski, Rebecca; ...
#
#                    pub_date  ... headline.kicker headline.content_kicker  \
# 0  2023-05-25T11:00:03+0000  ...            None                    None
# 1  2023-05-04T17:16:45+0000  ...            None                    None
# 2  2023-05-04T11:00:08+0000  ...            None                    None
# 3  2023-04-21T07:03:25+0000  ...            None                    None
# 4  2023-04-20T15:35:13+0000  ...   Critic’s pick                    None
#
#                   headline.print_headline headline.name headline.seo  \
# 0                  The Attachment Diaries          None         None
# 1          What’s Love Got to Do With It?          None         None
# 2                    You Can Live Forever          None         None
# 3              A Tourist’s  Guide to Love          None         None
# 4  Intoxicating Love With a Sobering Turn          None         None
#
#    headline.sub           byline.original  \
# 0          None    By Jeannette Catsoulis
# 1          None    By Jeannette Catsoulis
# 2          None  By Elisabeth Vincentelli
# 3          None  By Elisabeth Vincentelli
# 4          None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review
#
# [5 rows x 28 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles_list = df_reviews['title'].to_list()

# Display the list to verify the extracted titles
print(titles_list)
# Out:
# ['The Attachment Diaries Review', 'What Review', 'You Can Live Forever Review', 'A Tourist Review', 'Other People Review', 'One True Loves Review', 'The Lost Weekend: A Love Story Review', 'A Thousand and One Review', 'Your Place or Mine Review', 'Love in the Time of Fentanyl Review', 'The Attachment Diaries Review', 'What Review', 'You Can Live Forever Review', 'A Tourist Review', 'Other People Review', 'One True Loves Review', 'The Lost Weekend: A Love Story Review', 'A Thousand and One Review', 'Your Place or Mine Review', 'Love in the Time of Fentanyl Review', 'Pamela, a Love Story Review', 'In From the Side Review', 'After Love Review', 'Alcarràs Review', 'Nelly & Nadine Review', 'Lady Chatterley Review', 'The Sound of Christmas Review', 'The Inspection Review', 'Bones and All Review', 'My Policeman Review', 'Pamela, a Love Story Review', 'In From the Side Review', 'After Love Review', 'Alcarràs Review', 'Nelly & Nadine Review', 'Lady Chatterley Review', 'The Sound of Christmas Review', 'The Inspection Review', 'Bones and All Review', 'My Policeman Review', 'About Fate Review', 'Waiting for Bojangles Review', 'I Love My Dad Review', 'A Love Song Review', 'Alone Together Review', 'Art of Love Review', 'The Wheel Review', 'Thor: Love and Thunder Review', 'Both Sides of the Blade Review', 'Fire of Love Review', 'About Fate Review', 'Waiting for Bojangles Review', 'I Love My Dad Review', 'A Love Song Review', 'Alone Together Review', 'Art of Love Review', 'The Wheel Review', 'Thor: Love and Thunder Review', 'Both Sides of the Blade Review', 'Fire of Love Review', 'Love & Gelato Review', 'Stay Prayed Up Review', 'Benediction Review', 'Dinner in America Review', 'In a New York Minute Review', 'Anaïs in Love Review', 'I Love America Review', 'See You Then Review', 'La Mami Review', 'Love After Love Review', 'Love & Gelato Review', 'Stay Prayed Up Review', 'Benediction Review', 'Dinner in America Review', 'In a New York Minute Review', 'Anaïs in Love Review', 'I Love America Review', 'See You Then Review', 'La Mami Review', 'Love After Love Review', 'Deep Water Review', 'Lucy and Desi Review', 'Cyrano Review', 'The In Between Review', 'Book of Love Review', 'Lingui, the Sacred Bonds Review', 'The Pink Cloud Review', 'A Journal for Jordan Review', 'West Side Story Review', 'Aulcie Review', 'Deep Water Review', 'Lucy and Desi Review', 'Cyrano Review', 'The In Between Review', 'Book of Love Review', 'Lingui, the Sacred Bonds Review', 'The Pink Cloud Review', 'A Journal for Jordan Review', 'West Side Story Review', 'Aulcie Review', 'Love Is Love Is Love Review', 'Love Hard Review', 'Bergman Island Review', 'Hard Luck Love Song Review', 'South of Heaven Review', 'Wife of a Spy Review', 'Happier Than Ever Review', 'Together Review', 'Annette Review', 'Resort to Love Review', 'Love Is Love Is Love Review', 'Love Hard Review', 'Bergman Island Review', 'Hard Luck Love Song Review', 'South of Heaven Review', 'Wife of a Spy Review', 'Happier Than Ever Review', 'Together Review', 'Annette Review', 'Resort to Love Review', 'Woodstock 99: Peace, Love and Rage Review', 'Casanova, Last Love Review', 'Running Against the Wind Review', 'Asia Review', 'Undine Review', 'This Town Review', 'Tu Me Manques Review', 'Monday Review', 'Ride or Die Review', 'Future People Review', 'Woodstock 99: Peace, Love and Rage Review', 'Casanova, Last Love Review', 'Running Against the Wind Review', 'Asia Review', 'Undine Review', 'This Town Review', 'Tu Me Manques Review', 'Monday Review', 'Ride or Die Review', 'Future People Review', 'Luz Review', 'Happily Review', 'This Is the Life Review', 'To All the Boys: Always and Forever Review', 'Young Hearts Review', 'Little Fish Review', 'Two of Us Review', 'Atlantis Review', 'Preparations to Be Together Review', 'Your Name Engraved Herein Review', 'Luz Review', 'Happily Review', 'This Is the Life Review', 'To All the Boys: Always and Forever Review', 'Young Hearts Review', 'Little Fish Review', 'Two of Us Review', 'Atlan ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + TMDB_API_KEY

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple of 50 requests
request_counter = 0

# Loop through the titles
for title in titles_list:
    # Check if we need to sleep before making a request
    if request_counter > 0 and request_counter % 50 == 0:
        time.sleep(12)  # Sleep for 12 seconds after every 50 requests

    # Add 1 to the request counter
    request_counter += 1
    
    # Remove " Review" from the title to improve search results
    search_title = title.replace(" Review", "")
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(f"{url}{search_title}{tmdb_key_string}")
    
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie is not found.
    try:
        results = response.json().get('results', [])
        if results:
            # Get movie id
            movie_id = results[0]['id']

            # Make a request for the full movie details
            details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}"
            
            # Execute "GET" request with url
            details_response = requests.get(details_url)
            movie_details = details_response.json()
            
            # Extract the genre names into a list
            genres = [genre['name'] for genre in movie_details['genres']]
            
            # Extract the spoken_languages' English name into a list
            spoken_languages = [language['english_name'] for language in movie_details['spoken_languages']]
            
            # Extract the production_countries' name into a list
            production_countries = [country['name'] for country in movie_details['production_countries']]
            
            # Add the relevant data to a dictionary and append it to the tmdb_movies_list list
            tmdb_movies_list.append({
                'title': title,
                'genres': genres,
                'spoken_languages': spoken_languages,
                'production_countries': production_countries,
                'release_date': movie_details.get('release_date', 'N/A'),
                'runtime': movie_details.get('runtime', 'N/A'),
                'vote_average': movie_details.get('vote_average', 'N/A')
            })
            
            # Print out the title that was found
            print(f"Found details for: {title}")
        else:
            print(f"Movie not found: {title}")

    except (IndexError, KeyError):
        print(f"Movie not found: {title}")
# Out:
# Found details for: The Attachment Diaries Review
# Found details for: What Review
# Found details for: You Can Live Forever Review
# Found details for: A Tourist Review
# Found details for: Other People Review
# Found details for: One True Loves Review
# Found details for: The Lost Weekend: A Love Story Review
# Found details for: A Thousand and One Review
# Found details for: Your Place or Mine Review
# Found details for: Love in the Time of Fentanyl Review
# Found details for: The Attachment Diaries Review
# Found details for: What Review
# Found details for: You Can Live Forever Review
# Found details for: A Tourist Review
# Found details for: Other People Review
# Found details for: One True Loves Review
# Found details for: The Lost Weekend: A Love Story Review
# Found details for: A Thousand and One Review
# Found details for: Your Place or Mine Review
# Found details for: Love in the Time of Fentanyl Review
# Found details for: Pamela, a Love Story Review
# Found details for: In From the Side Review
# Found details for: After Love Review
# Found details for: Alcarràs Review
# Found details for: Nelly & Nadine Review
# Found details for: Lady Chatterley Review
# Found details for: The Sound of Christmas Review
# Found details for: The Inspection Review
# Found details for: Bones and All Review
# Found details for: My Policeman Review
# Found details for: Pamela, a Love Story Review
# Found details for: In From the Side Review
# Found details for: After Love Review
# Found details for: Alcarràs Review
# Found details for: Nelly & Nadine Review
# Found details for: Lady Chatterley Review
# Found details for: The Sound of Christmas Review
# Found details for: The Inspection Review
# Found details for: Bones and All Review
# Found details for: My Policeman Review
# Found details for: About Fate Review
# Found details for: Waiting for Bojangles Review
# Found details for: I Love My Dad Review
# Found details for: A Love Song Review
# Found details for: Alone Together Review
# Found details for: Art of Love Review
# Found details for: The Wheel Review
# Found details for: Thor: Love and Thunder Review
# Found details for: Both Sides of the Blade Review
# Found details for: Fire of Love Review
# Found details for: About Fate Review
# Found details for: Waiting for Bojangles Review
# Found details for: I Love My Dad Review
# Found details for: A Love Song Review
# Found details for: Alone Together Review
# Found details for: Art of Love Review
# Found details for: The Wheel Review
# Found details for: Thor: Love and Thunder Review
# Found details for: Both Sides of the Blade Review
# Found details for: Fire of Love Review
# Found details for: Love & Gelato Review
# Found details for: Stay Prayed Up Review
# Found details for: Benediction Review
# Found details for: Dinner in America Review
# Found details for: In a New York Minute Review
# Found details for: Anaïs in Love Review
# Found details for: I Love America Review
# Found details for: See You Then Review
# Found details for: La Mami Review
# Found details for: Love After Love Review
# Found details for: Love & Gelato Review
# Found details for: Stay Prayed Up Review
# Found details for: Benediction Review
# Found details for: Dinner in America Review
# Found details for: In a New York Minute Review
# Found details for: Anaïs in Love Review
# Found details for: I Love America Review
# Found details for: See You Then Review
# Found details for: La Mami Review
# Found details for: Love After Love Review
# Found details for: Deep Water Review
# Found details for: Lucy and Desi Review
# Found details for: Cyrano Review
# Found details for: The In Between Review
# Found details for: Book of Love Review
# Found details for: Lingui, the Sacred Bonds Review
# Found details for: The Pink Cloud Review
# Found details for: A Journal for Jordan Review
# Found details for: West Side Story Review
# Movie not found: Aulcie Review
# Found details for: Deep Water Review
# Found details for: Lucy and Desi Review
# Found details for: Cyrano Review
# Found details for: The In Between Review
# Found details for: Book of Love Review
# Found details for: Lingui, the Sacred Bonds Review
# Found details for: The Pink Cloud Review
# Found details for: A Journal for Jordan Review
# Found details for: West Side Story Review
# Movie not found: Aulcie Review
# Found details for: Love Is Love Is Love Review
# Found details for: Love Hard Review
# Found details for: Bergman Island Review
# Found details for: Hard Luck Love Song Review
# Found details for: South of Heaven Review
# Found details for: Wife of a Spy Review
# Found details for: Happier Than Ever Review
# Found details for: Together Review
# Found details for: Annette Review
# Found details for: Resort to Love Review
# Found details for: Love Is Love Is Love Review
# Found details for: Love Hard Review
# Found details for: Bergman Island Review
# Found details for: Hard Luck Love Song Review
# Found details for: South of Heaven Review
# Found details for: Wife of a Spy Review
# Found details for: Happier Than Ever Review
# Found details for: Together Review
# Found details for: Annette Review
# Found details for: Resort to Love Review
# Found details for: Woodstock 99: Peace, Love and Rage Review
# Found details for: Casanova, Last Love Review
# Found details for: Running Against the Wind Review
# Found details for: Asia Review
# Found details for: Undine Review
# Found details for: This Town Review
# Found details for: Tu Me Manques Review
# Found details for: Monday Review
# Found details for: Ride or Die Review
# Found details for: Future People Review
# Found details for: Woodstock 99: Peace, Love and Rage Review
# Found details for: Casanova, Last Love Review
# Found details for: Running Against the Wind Review
# Found details for: Asia Review
# Found details for: Undine Review
# Found details for: This Town Review
# Found details for: Tu Me Manques Review
# Found details for: Monday Review
# Found details for: Ride or Die Review
# Found details for: Future People Review
# Found details for: Luz Review
# Found details for: Happily Review
# Found details for: This Is the Life Review
# Found details for: To All the Boys: Always and Forever Review
# Found details for: Young Hearts Review
# Found details for: Little Fish Review
# Found details for: Two of Us Review
# Found details for: Atlantis Review
# Found details for: Preparations to Be Together Review
# Found details for: Your Name Engraved Herein Review
# Found details for: Luz Review
# Found details for: Happily Review
# Found details for: This Is the Life Review
# Found details for: To All the Boys: Always and Forever Review
# Found details for: Young Hearts Review
# Found details for: Little Fish Review
# Found details for: Two of Us Review
# Found details for: Atlantis Review
# Found details for: Preparations to Be Together Review
# Found details for: Your Name Engraved Herein Review
# Found details for: Sylvie Review
# Found details for: Ariana Grande: Excuse Me, I Love You Review
# Found details for: Museum Town Review
# Found details for: Wild Mountain Thyme Review
# Found details for: My Psychedelic Love Story Review
# Found details for: 69: The Saga of Danny Hernandez Review
# Found details for: Ammonite Review
# Found details for: Love and Monsters Review
# Found details for: Dick Johnson Is Dead Review
# Found details for: Love, Guaranteed Review
# Found details for: Sylvie Review
# Found details for: Ariana Grande: Excuse Me, I Love You Review
# Found details for: Museum Town Review
# Found details for: Wild Mountain Thyme Review
# Found details for: My Psychedelic Love Story Review
# Found details for: 69: The Saga of Danny Hernandez Review
# Found details for: Ammonite Review
# Found details for: Love and Monsters Review
# Found details for: Dick Johnson Is Dead Review
# Found details for: Love, Guaranteed Review
# Found details for: Feel the Beat Review
# Found details for: Babyteeth Review
# Found details for: Spelling the Dream Review
# Found details for: A Secret Love Review
# Found details for: Love Wedding Repeat Review
# Found details for: Almost Love Review
# Found details for: Hope Gap Review
# Found details for: All the Bright Places Review
# Found details for: The Photograph Review
# Found details for: You Go to My Head Review
# Found details for: Feel the Beat Review
# Found details for: Babyteeth Review
# Found details for: Spelling the Dream Review
# Found details for: A Secret Love Review
# Found details for: Love Wedding Repeat Review
# Found details for: Almost Love Review
# Found details for: Hope Gap Review
# Found details for: All the Bright Places Review
# Found details for: The Photograph Review
# Found details for: You Go to My Head Review
# Found details for: Ordinary Love Review
# Found details for: To All the Boys: P.S. I Still Love You Review
# Found details for: The Woman Who Loves Giraffes Review
# Found details for: Queen & Slim Review
# Found details for: Marriage Story Review
# Found details for: Cyrano, My Love Review
# Found details for: Pretenders Review
# Found details for: First Love Review
# Found details for: Loro Review
# Found details for: Falling Inn Love Review
# Found details for: Ordinary Love Review
# Found details for: To All the Boys: P.S. I Still Love You Review
# Found details for: The Woman Who Loves Giraffes Review
# Found details for: Queen & Slim Review
# Found details for: Marriage Story Review
# Found details for: Cyrano, My Love Review
# Found details for: Pretenders Review
# Found details for: First Love Review
# Found details for: Loro Review
# Found details for: Falling Inn Love Review
# Found details for: Hot Air Review
# Found details for: Love, Antosha Review
# Found details for: Leto Review
# Found details for: The Tomorrow Man Review
# Found details for: Asako I & II Review
# Found details for: The Sun Is Also a Star Review
# Found details for: Shéhérazade Review
# Found details for: Long Shot Review
# Found details for: Clara Review
# Found details for: Kalank Review
# Found details for: Hot Air Review
# Found details for: Love, Antosha Review
# Found details for: Leto Review
# Found details for: The Tomorrow Man Review
# Found details for: Asako I & II Review
# Found details for: The Sun Is Also a Star Review
# Found details for: Shéhérazade Review
# Found details for: Long Shot Review
# Found details for: Clara Review
# Found details for: Kalank Review
# Found details for: Rafiki Review
# Found details for: Diane Review
# Found details for: Five Feet Apart Review
# Found details for: Ash Is Purest White Review
# Found details for: Gloria Bell Review
# Found details for: Black Mother Review
# Found details for: The Hole in the Ground Review
# Found details for: How to Train Your Dragon: The Hidden World Review
# Found details for: A Tuba to Cuba Review
# Found details for: Fighting With My Family Review
# Found details for: Rafiki Review
# Found details for: Diane Review
# Found details for: Five Feet Apart Review
# Found details for: Ash Is Purest White Review
# Found details for: Gloria Bell Review
# Found details for: Black Mother Review
# Found details for: The Hole in the Ground Review
# Found details for: How to Train Your Dragon: The Hidden World Review
# Found details for: A Tuba to Cuba Review
# Found details for: Fighting With My Family Review
# Found details for: Sorry Angel Review
# Found details for: Berlin, I Love You Review
# Found details for: Untogether Review
# Found details for: Cold War Review
# Found details for: If Beale Street Could Talk Review
# Found details for: Asher Review
# Found details for: The Party Review
# Found details for: The Great Pretender Review
# Found details for: Sicilian Ghost Story Review
# Found details for: The New Romantic Review
# Found details for: Sorry Angel Review
# Found details for: Berlin, I Love You Review
# Found details for: Untogether Review
# Found details for: Cold War Review
# Found details for: If Beale Street Could Talk Review
# Found details for: Asher Review
# Found details for: The Party Review
# Found details for: The Great Pretender Review
# Found details for: Sicilian Ghost Story Review
# Found details for: The New Romantic Review
# Found details for: Pimp Review
# Found details for: In a Relationship Review
# Found details for: They Review
# Found details for: Burning, Review
# Found details for: After Everything, Review
# Found details for: Quincy Review
# Found details for: Love, Gilda, Review
# Found details for: Tea With the Dames, Review
# Found details for: Bel Canto, Review
# Found details for: The Citizen, Review
# Found details for: Pimp Review
# Found details for: In a Relationship Review
# Found details for: They Review
# Found details for: Burning, Review
# Found details for: After Everything, Review
# Found details for: Quincy Review
# Found details for: Love, Gilda, Review
# Found details for: Tea With the Dames, Review
# Found details for: Bel Canto, Review
# Found details for: The Citizen, Review
# Found details for: Love, Cecil, Review
# Found details for: How to Talk to Girls at Parties Review
# Found details for: Rogers Park, Review
# Found details for: Love & Bananas, Review
# Movie not found:  Review
# Found details for: Submergence, Review
# Found details for: Love After Love, Review
# Found details for: Outside In Review
# Found details for: Love, Simon, Review
# Found details for: Keep the Change, Review
# Found details for: Love, Cecil, Review
# Found details for: How to Talk to Girls at Parties Review
# Found details for: Rogers Park, Review
# Found details for: Love & Bananas, Review
# Movie not found:  Review
# Found details for: Submergence, Review
# Found details for: Love After Love, Review
# Found details for: Outside In Review
# Found details for: Love, Simon, Review
# Found details for: Keep the Change, Review
# Found details for: The Party Review
# Found details for: The Housemaid, Review
# Found details for: Forever My Girl, Review
# Found details for: Kangaroo: A Love-Hate Story Review
# Found details for: Lover for a Day Review
# Found details for: Youth, Review
# Found details for: Killing for Love Review
# Found details for: The Shape of Water Review
# Found details for: Love Beats Rhymes, Review
# Found details for: Cuba and the Cameraman Review
# Found details for: The Party Review
# Found details for: The Housemaid, Review
# Found details for: Forever My Girl, Review
# Found details for: Kangaroo: A Love-Hate Story Review
# Found details for: Lover for a Day Review
# Found details for: Youth, Review
# Found details for: Killing for Love Review
# Found details for: The Shape of Water Review
# Found details for: Love Beats Rhymes, Review
# Found details for: Cuba and the Cameraman Review
# Found details for: On the Beach at Night Alone Review
# Found details for: Thelma, Review
# Found details for: Hello Again, Review
# Found details for: It Happened in L.A., Review
# Found details for: God Review
# Found details for: The Mountain Between Us Review
# Found details for: Dina, Review
# Found details for: In Search of Fellini Review
# Found details for: Woodpeckers, Review
# Found details for: I Do ... Until I Don Review
# Found details for: On the Beach at Night Alone Review
# Found details for: Thelma, Review
# Found details for: Hello Again, Review
# Found details for: It Happened in L.A., Review
# Found details for: God Review
# Found details for: The Mountain Between Us Review
# Found details for: Dina, Review
# Found details for: In Search of Fellini Review
# Found details for: Woodpeckers, Review
# Found details for: I Do ... Until I Don Review
# Found details for: Tales of an Immoral Couple Review
# Found details for: After Love Review
# Movie not found:  Review
# Found details for: Women Who Kill, Review
# Found details for: False Confessions, Review
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 17
#      14 request_counter += 1
#      16 # Remove " Review" from the title to improve search results
# ---> 17 search_title = title.replace(" Review", "")
#      19 # Perform a "GET" request for The Movie Database
#      20 response = requests.get(f"{url}{search_title}{tmdb_key_string}")
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
# Preview the first 5 results in JSON format
formatted_results = json.dumps(tmdb_movies_list[:5], indent=4)

# Print the formatted JSON results
print(formatted_results)
# Out:
# [
#     {
#         "title": "The Attachment Diaries Review",
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ],
#         "release_date": "2021-10-07",
#         "runtime": 102,
#         "vote_average": 3.0
#     },
#     {
#         "title": "What Review",
#         "genres": [
#             "Comedy"
#         ],
#         "spoken_languages": [],
#         "production_countries": [
#             "United States of America"
#         ],
#         "release_date": "2022-04-08",
#         "runtime": 100,
#         "vote_average": 5.9
#     },
#     {
#         "title": "You Can Live Forever Review",
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ],
#         "release_date": "2023-03-24",
#         "runtime": 96,
#         "vote_average": 6.55
#     },
#     {
#         "title": "A Tourist Review",
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_countries": [
#             "United States of America"
#         ],
#         "release_date": "2023-04-21",
#         "runtime": 96,
#         "vote_average": 6.303
#     },
#     {
#         "title": "Other People Review",
#         "genres": [
#             "Comedy",
#             "Drama"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ],
#         "release_date": "2016-09-09",
#         "runtime": 97,
#         "vote_average": 6.312
#     }
# ]

# %%
# Convert the results to a DataFrame
df_tmdb_movies = pd.DataFrame(tmdb_movies_list)

# Display the first few rows of the DataFrame to verify the conversion
df_tmdb_movies
# Out:
#                                  title  \
# 0        The Attachment Diaries Review
# 1                          What Review
# 2          You Can Live Forever Review
# 3                     A Tourist Review
# 4                  Other People Review
# ..                                 ...
# 355        I Do ... Until I Don Review
# 356  Tales of an Immoral Couple Review
# 357                  After Love Review
# 358             Women Who Kill, Review
# 359          False Confessions, Review
#
#                                           genres  \
# 0             [Drama, Mystery, Thriller, Horror]
# 1                                       [Comedy]
# 2                               [Drama, Romance]
# 3                              [Romance, Comedy]
# 4                                [Comedy, Drama]
# ..                                           ...
# 355                                     [Comedy]
# 356                            [Comedy, Romance]
# 357                                      [Drama]
# 358  [Comedy, Crime, Mystery, Romance, Thriller]
# 359                                [Documentary]
#
#                     spoken_languages                 production_countries  \
# 0                          [Spanish]                          [Argentina]
# 1                                 []           [United States of America]
# 2                  [English, French]   [Canada, United States of America]
# 3              [English, Vietnamese]           [United States of America]
# 4                          [English]           [United States of America]
# ..                               ...                                  ...
# 355                        [English]           [United States of America]
# 356                        [Spanish]                             [Mexico]
# 357  [English, Arabic, French, Urdu]                     [United Kingdom]
# 358                        [English]           [United States of America]
# 359                        [English]  [Denmark, United States of America]
#
#     release_date  runtime  vote_average
# 0     2021-10-07      102         3.000
# 1     2022-04-08      100         5.900
# 2     2023-03-24       96         6.550
# 3     2023-04-21       96         6.303
# 4     2016-09-09       97         6.312
# ..           ...      ...           ...
# 355   2017-09-01      103         4.985
# 356   2016-10-28       91         6.500
# 357   2021-06-04       89         7.164
# 358   2016-07-27       93         4.900
# 359   2018-03-17       91         8.200
#
# [360 rows x 7 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews DataFrame (df_reviews) and TMDB DataFrame (df_tmdb_movies) on the 'title' column
merged_df = pd.merge(df_reviews, df_tmdb_movies, on='title', how='inner')

# Display the first few rows of the merged DataFrame to verify the merge
merged_df.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/04/movies/what...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A trashy treat coated in a high-art gloss, “Th...             C          7
# 2  A trashy treat coated in a high-art gloss, “Th...             C          7
# 3  A trashy treat coated in a high-art gloss, “Th...             C          7
# 4  A glossy lesson in how to pour nontraditional ...             C          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  subject: Movies; creative_works: The Attachmen...
# 1  subject: Movies; creative_works: The Attachmen...
# 2  subject: Movies; creative_works: The Attachmen...
# 3  subject: Movies; creative_works: The Attachmen...
# 4  subject: Movies; persons: Kapur, Shekhar; pers...
#
#                    pub_date  ...         byline.original  \
# 0  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 1  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 2  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 3  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 4  2023-05-04T17:16:45+0000  ...  By Jeannette Catsoulis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Jeannette', 'middlename': None...                None
# 3  [{'firstname': 'Jeannette', 'middlename': None...                None
# 4  [{'firstname': 'Jeannette', 'middlename': None...                None
#
#                            title                              genres  \
# 0  The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 1  The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 2  The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 3  The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 4                    What Review                            [Comedy]
#
#    spoken_languages        production_countries release_date runtime  \
# 0         [Spanish]                 [Argentina]   2021-10-07     102
# 1         [Spanish]                 [Argentina]   2021-10-07     102
# 2         [Spanish]                 [Argentina]   2021-10-07     102
# 3         [Spanish]                 [Argentina]   2021-10-07     102
# 4                []  [United States of America]   2022-04-08     100
#
#   vote_average
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          5.9
#
# [5 rows x 34 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing (that contain lists)
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
chars_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str' if it's not already a string
    merged_df[column] = merged_df[column].astype(str)
    
    # Loop through characters to remove
    for char in chars_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, "")
        
# Display the fixed DataFrame
merged_df.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/04/movies/what...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A trashy treat coated in a high-art gloss, “Th...             C          7
# 2  A trashy treat coated in a high-art gloss, “Th...             C          7
# 3  A trashy treat coated in a high-art gloss, “Th...             C          7
# 4  A glossy lesson in how to pour nontraditional ...             C          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  subject: Movies; creative_works: The Attachmen...
# 1  subject: Movies; creative_works: The Attachmen...
# 2  subject: Movies; creative_works: The Attachmen...
# 3  subject: Movies; creative_works: The Attachmen...
# 4  subject: Movies; persons: Kapur, Shekhar; pers...
#
#                    pub_date  ...         byline.original  \
# 0  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 1  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 2  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 3  2023-05-25T11:00:03+0000  ...  By Jeannette Catsoulis
# 4  2023-05-04T17:16:45+0000  ...  By Jeannette Catsoulis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Jeannette', 'middlename': None...                None
# 3  [{'firstname': 'Jeannette', 'middlename': None...                None
# 4  [{'firstname': 'Jeannette', 'middlename': None...                None
#
#                            title                            genres  \
# 0  The Attachment Diaries Review  Drama, Mystery, Thriller, Horror
# 1  The Attachment Diaries Review  Drama, Mystery, Thriller, Horror
# 2  The Attachment Diaries Review  Drama, Mystery, Thriller, Horror
# 3  The Attachment Diaries Review  Drama, Mystery, Thriller, Horror
# 4                    What Review                            Comedy
#
#    spoken_languages      production_countries release_date runtime  \
# 0           Spanish                 Argentina   2021-10-07     102
# 1           Spanish                 Argentina   2021-10-07     102
# 2           Spanish                 Argentina   2021-10-07     102
# 3           Spanish                 Argentina   2021-10-07     102
# 4                    United States of America   2022-04-08     100
#
#   vote_average
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          5.9
#
# [5 rows x 34 columns]

# %%
# Drop the "byline.person" column
merged_df = merged_df.drop(columns=['byline.person'])

# Display the first few rows of the DataFrame to verify the column is dropped
merged_df.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/04/movies/what...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  A gynecologist and her patient form a horrifyi...
# 2  A gynecologist and her patient form a horrifyi...
# 3  A gynecologist and her patient form a horrifyi...
# 4  Two childhood friends navigate cultural differ...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A trashy treat coated in a high-art gloss, “Th...             C          7
# 2  A trashy treat coated in a high-art gloss, “Th...             C          7
# 3  A trashy treat coated in a high-art gloss, “Th...             C          7
# 4  A glossy lesson in how to pour nontraditional ...             C          8
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  subject: Movies; creative_works: The Attachmen...
# 1  subject: Movies; creative_works: The Attachmen...
# 2  subject: Movies; creative_works: The Attachmen...
# 3  subject: Movies; creative_works: The Attachmen...
# 4  subject: Movies; persons: Kapur, Shekhar; pers...
#
#                    pub_date  ... headline.sub         byline.original  \
# 0  2023-05-25T11:00:03+0000  ...         None  By Jeannette Catsoulis
# 1  2023-05-25T11:00:03+0000  ...         None  By Jeannette Catsoulis
# 2  2023-05-25T11:00:03+0000  ...         None  By Jeannette Catsoulis
# 3  2023-05-25T11:00:03+0000  ...         None  By Jeannette Catsoulis
# 4  2023-05-04T17:16:45+0000  ...         None  By Jeannette Catsoulis
#
#   byline.organization                          title  \
# 0                None  The Attachment Diaries Review
# 1                None  The Attachment Diaries Review
# 2                None  The Attachment Diaries Review
# 3                None  The Attachment Diaries Review
# 4                None                    What Review
#
#                              genres  spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror           Spanish
# 1  Drama, Mystery, Thriller, Horror           Spanish
# 2  Drama, Mystery, Thriller, Horror           Spanish
# 3  Drama, Mystery, Thriller, Horror           Spanish
# 4                            Comedy
#
#        production_countries release_date runtime vote_average
# 0                 Argentina   2021-10-07     102          3.0
# 1                 Argentina   2021-10-07     102          3.0
# 2                 Argentina   2021-10-07     102          3.0
# 3                 Argentina   2021-10-07     102          3.0
# 4  United States of America   2022-04-08     100          5.9
#
# [5 rows x 33 columns]

# %%
#Print unique data types in each column
for col in merged_df.columns:
    print(f"Column '{col}' unique types:", merged_df[col].map(type).unique())
# Out:
# Column 'abstract' unique types: [<class 'str'>]
# Column 'web_url' unique types: [<class 'str'>]
# Column 'snippet' unique types: [<class 'str'>]
# Column 'lead_paragraph' unique types: [<class 'str'>]
# Column 'print_section' unique types: [<class 'str'> <class 'float'>]
# Column 'print_page' unique types: [<class 'str'> <class 'float'>]
# Column 'source' unique types: [<class 'str'>]
# Column 'multimedia' unique types: [<class 'tuple'>]
# Column 'keywords' unique types: [<class 'str'>]
# Column 'pub_date' unique types: [<class 'str'>]
# Column 'document_type' unique types: [<class 'str'>]
# Column 'news_desk' unique types: [<class 'str'>]
# Column 'section_name' unique types: [<class 'str'>]
# Column 'type_of_material' unique types: [<class 'str'>]
# Column '_id' unique types: [<class 'str'>]
# Column 'word_count' unique types: [<class 'int'>]
# Column 'uri' unique types: [<class 'str'>]
# Column 'headline.main' unique types: [<class 'str'>]
# Column 'headline.kicker' unique types: [<class 'NoneType'> <class 'str'>]
# Column 'headline.content_kicker' unique types: [<class 'NoneType'>]
# Column 'headline.print_headline' unique types: [<class 'str'> <class 'NoneType'>]
# Column 'headline.name' unique types: [<class 'NoneType'>]
# Column 'headline.seo' unique types: [<class 'NoneType'>]
# Column 'headline.sub' unique types: [<class 'NoneType'>]
# Column 'byline.original' unique types: [<class 'str'>]
# Column 'byline.organization' unique types: [<class 'NoneType'>]
# Column 'title' unique types: [<class 'str'>]
# Column 'genres' unique types: [<class 'str'>]
# Column 'spoken_languages' unique types: [<class 'str'>]
# Column 'production_countries' unique types: [<class 'str'>]
# Column 'release_date' unique types: [<class 'str'>]
# Column 'runtime' unique types: [<class 'int'>]
# Column 'vote_average' unique types: [<class 'float'>]

# %%
# Convert mixed-type columns to strings
columns_to_convert = ['print_section', 'print_page', 'headline.kicker', 'headline.print_headline', 
                      'byline.organization', 'headline.content_kicker', 'headline.name', 
                      'headline.seo', 'headline.sub']

for col in columns_to_convert:
    merged_df[col] = merged_df[col].astype(str)

# Convert `NoneType` to empty strings
merged_df = merged_df.fillna('')

# Convert tuples to strings in 'multimedia' column
merged_df['multimedia'] = merged_df['multimedia'].apply(str)

# Delete duplicate rows
merged_df = merged_df.drop_duplicates()

# Reset the index
merged_df = merged_df.reset_index(drop=True)

# Display the first few rows of the DataFrame to verify the changes
merged_df.head()
# Out:
#                                             abstract  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet  \
# 0  A gynecologist and her patient form a horrifyi...
# 1  Two childhood friends navigate cultural differ...
# 2  Religion comes between two girls falling in lo...
# 3  Rachael Leigh Cook stars in this bland rom-com...
# 4  A radiant Virginie Efira stars as a Parisian t...
#
#                                       lead_paragraph print_section print_page  \
# 0  A trashy treat coated in a high-art gloss, “Th...             C          7
# 1  A glossy lesson in how to pour nontraditional ...             C          8
# 2  In “You Can Live Forever,” Jaime and Marike do...             C          9
# 3  The first thing we learn about Amanda (Rachael...             C          7
# 4  When a woman falls in love in the sensitive Fr...             C          4
#
#                source                                         multimedia  \
# 0  The New York Times  ({'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  ({'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times  ({'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  The New York Times  ({'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  The New York Times  ({'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  subject: Movies; creative_works: The Attachmen...
# 1  subject: Movies; persons: Kapur, Shekhar; pers...
# 2  subject: Movies; creative_works: You Can Live ...
# 3  subject: Movies; creative_works: A Tourist's G...
# 4  subject: Movies; persons: Zlotowski, Rebecca; ...
#
#                    pub_date  ... headline.sub           byline.original  \
# 0  2023-05-25T11:00:03+0000  ...         None    By Jeannette Catsoulis
# 1  2023-05-04T17:16:45+0000  ...         None    By Jeannette Catsoulis
# 2  2023-05-04T11:00:08+0000  ...         None  By Elisabeth Vincentelli
# 3  2023-04-21T07:03:25+0000  ...         None  By Elisabeth Vincentelli
# 4  2023-04-20T15:35:13+0000  ...         None         By Manohla Dargis
#
#   byline.organization                          title  \
# 0                None  The Attachment Diaries Review
# 1                None                    What Review
# 2                None    You Can Live Forever Review
# 3                None               A Tourist Review
# 4                None            Other People Review
#
#                              genres     spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror              Spanish
# 1                            Comedy
# 2                    Drama, Romance      English, French
# 3                   Romance, Comedy  English, Vietnamese
# 4                     Comedy, Drama              English
#
#                production_countries release_date runtime vote_average
# 0                         Argentina   2021-10-07     102        3.000
# 1          United States of America   2022-04-08     100        5.900
# 2  Canada, United States of America   2023-03-24      96        6.550
# 3          United States of America   2023-04-21      96        6.303
# 4          United States of America   2016-09-09      97        6.312
#
# [5 rows x 33 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv('cleaned_data.csv', index=False)

print("Data successfully exported to 'cleaned_data.csv'")
# Out:
# Data successfully exported to 'cleaned_data.csv'
